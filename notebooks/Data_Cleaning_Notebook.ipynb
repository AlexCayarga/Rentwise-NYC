# %%
import pandas as pd

from google.colab import files
uploaded = files.upload()

df = pd.read_csv("column_cleaned_train.csv")
df.head()
# Out:
#      <input type="file" id="files-a1d44f2b-c37b-4759-94d5-8b3740aed1c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1d44f2b-c37b-4759-94d5-8b3740aed1c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 2. Explore the Data

# %%
# Shape and basic info
df.shape
# Out:
# (49352, 15)

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2623/3771845804.py in <cell line: 0>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.describe()
# Out:
#            bedrooms    bathrooms      latitude    listing_id     longitude  \
# count  49352.000000  49352.00000  49352.000000  4.935200e+04  49352.000000
# mean       1.541640      1.21218     40.741545  7.024055e+06    -73.955716
# std        1.115018      0.50142      0.638535  1.262746e+05      1.177912
# min        0.000000      0.00000      0.000000  6.811957e+06   -118.271000
# 25%        1.000000      1.00000     40.728300  6.915888e+06    -73.991700
# 50%        1.000000      1.00000     40.751800  7.021070e+06    -73.977900
# 75%        2.000000      1.00000     40.774300  7.128733e+06    -73.954800
# max        8.000000     10.00000     44.883500  7.753784e+06      0.000000
#
#               price   has_laundry  has_elevator   has_doorman  has_dishwasher  \
# count  4.935200e+04  49352.000000  49352.000000  49352.000000    49352.000000
# mean   3.830174e+03      0.484033      0.532359      0.426264        0.421989
# ...

# %%
# Basic statistics
df.describe(include='all')
# Out:
#            bedrooms    bathrooms      latitude    listing_id     longitude  \
# count  49352.000000  49352.00000  49352.000000  4.935200e+04  49352.000000
# mean       1.541640      1.21218     40.741545  7.024055e+06    -73.955716
# std        1.115018      0.50142      0.638535  1.262746e+05      1.177912
# min        0.000000      0.00000      0.000000  6.811957e+06   -118.271000
# 25%        1.000000      1.00000     40.728300  6.915888e+06    -73.991700
# 50%        1.000000      1.00000     40.751800  7.021070e+06    -73.977900
# 75%        2.000000      1.00000     40.774300  7.128733e+06    -73.954800
# max        8.000000     10.00000     44.883500  7.753784e+06      0.000000
#
#               price   has_laundry  has_elevator   has_doorman  has_dishwasher  \
# count  4.935200e+04  49352.000000  49352.000000  49352.000000    49352.000000
# mean   3.830174e+03      0.484033      0.532359      0.426264        0.421989
# ...

# %%
df["price"].describe()
# Out:
# count    4.935200e+04
# mean     3.830174e+03
# std      2.206687e+04
# min      4.300000e+01
# 25%      2.500000e+03
# 50%      3.150000e+03
# 75%      4.100000e+03
# max      4.490000e+06
# Name: price, dtype: float64

# %%
df["price"].sort_values(ascending=True).head(20)
# Out:
# 21118      43
# 34814      45
# 46673     401
# 45133     695
# 34103     695
# 45155     695
# 40899     695
# 8987      700
# 43409     800
# 24320     868
# 3204      950
# 30752     950
# 20247     950
# 34205     975
# 36336     980
# 45947     999
# 35145     999
# 33294     999
# 38158     999
# 7013     1000
# Name: price, dtype: int64

# %%
df["price"].sort_values(ascending=True).tail(530)
# Out:
# 24530      12500
# 22728      12500
# 47206      12600
# 20118      12600
# 29110      12600
#           ...
# 49289     135000
# 22058    1070000
# 22968    1070000
# 4793     1150000
# 12947    4490000
# Name: price, Length: 530, dtype: int64

# %%
import matplotlib.pyplot as plt

df["price"].plot(kind="hist", bins=100000)

plt.xlim(0, 15000)
plt.xlabel("Price")
plt.ylabel("Number of listings")
plt.title("Distribution of Apartment Prices Under 20,000")
plt.show()

# %% [markdown]
# ## 3. Identifying Missing Data

# %%
# Count missing values per column
df.isnull().sum()
# Out:
# bedrooms          0
# bathrooms         0
# latitude          0
# listing_id        0
# longitude         0
# price             0
# has_laundry       0
# has_elevator      0
# has_doorman       0
# has_dishwasher    0
# has_hardwood      0
# has_no_fee        0
# pets_allowed      0
# num_features      0
# is_studio         0
# dtype: int64

# %%
df.isnull()
# Out:
#        bedrooms  bathrooms  latitude  listing_id  longitude  price  \
# 0         False      False     False       False      False  False
# 1         False      False     False       False      False  False
# 2         False      False     False       False      False  False
# 3         False      False     False       False      False  False
# 4         False      False     False       False      False  False
# ...         ...        ...       ...         ...        ...    ...
# 49347     False      False     False       False      False  False
# 49348     False      False     False       False      False  False
# 49349     False      False     False       False      False  False
# 49350     False      False     False       False      False  False
# 49351     False      False     False       False      False  False
#
#        has_laundry  has_elevator  has_doorman  has_dishwasher  has_hardwood  \
# 0            False         False        False           False         False
# ...

# %%
# Visual summary of missing data
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ## 4. Handling Missing Data

# %%
df.shape
# Out:
# (49352, 15)

# %%
df['price'].median()
# Out:
# 3150.0

# %%
df['price']
# Out:
# 0        2400
# 1        3800
# 2        3495
# 3        3000
# 4        2795
#          ...
# 49347    2800
# 49348    2395
# 49349    1850
# 49350    4195
# 49351    4280
# Name: price, Length: 49352, dtype: int64

# %%
df
# Out:
#        bedrooms  bathrooms  latitude  listing_id  longitude  price  \
# 0             1        1.0   40.7108     7170325   -73.9539   2400
# 1             2        1.0   40.7513     7092344   -73.9722   3800
# 2             2        1.0   40.7575     7158677   -73.9625   3495
# 3             3        1.5   40.7145     7211212   -73.9425   3000
# 4             0        1.0   40.7439     7225292   -73.9743   2795
# ...         ...        ...       ...         ...        ...    ...
# 49347         3        1.0   40.8433     6824800   -73.9396   2800
# 49348         2        1.0   40.8198     6813268   -73.9578   2395
# 49349         1        1.0   40.5765     6927093   -73.9554   1850
# 49350         2        1.0   40.7448     6892816   -74.0017   4195
# 49351         3        1.0   40.7594     6901023   -73.9712   4280
#
#        has_laundry  has_elevator  has_doorman  has_dishwasher  has_hardwood  \
# 0                1             0            0               1             1
# ...

# %%
df.isnull().sum()
# Out:
# bedrooms          0
# bathrooms         0
# latitude          0
# listing_id        0
# longitude         0
# price             0
# has_laundry       0
# has_elevator      0
# has_doorman       0
# has_dishwasher    0
# has_hardwood      0
# has_no_fee        0
# pets_allowed      0
# num_features      0
# is_studio         0
# dtype: int64

# %% [markdown]
# ## 5. Detecting and Removing Duplicates

# %%
# Check for duplicates
duplicates = df.duplicated().sum()
#
print("Number of duplicate rows: "+str(duplicates))
# Out:
# Number of duplicate rows: 0

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49347    False
# 49348    False
# 49349    False
# 49350    False
# 49351    False
# Length: 49352, dtype: bool

# %%
# Show duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [bedrooms, bathrooms, latitude, listing_id, longitude, price, has_laundry, has_elevator, has_doorman, has_dishwasher, has_hardwood, has_no_fee, pets_allowed, num_features, is_studio]
# Index: []

# %% [markdown]
# ## 6. Data Types

# %%
df.dtypes
# Out:
# bedrooms            int64
# bathrooms         float64
# latitude          float64
# listing_id          int64
# longitude         float64
# price               int64
# has_laundry         int64
# has_elevator        int64
# has_doorman         int64
# has_dishwasher      int64
# has_hardwood        int64
# has_no_fee          int64
# pets_allowed        int64
# num_features        int64
# is_studio           int64
# dtype: object
